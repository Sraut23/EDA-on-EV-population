# %% [markdown]
# #What is Exploratory Data Analysis?
#
# *   Exploratory Data Analysis (EDA) is the process of analyzing a dataset in order to understand its main characteristics, patterns and identify anomalies. EDA is often the first step in the data analysis process.
# *   It involves using different graphs and plots to help visualise the data and also uses statistical methods to draw inferences from the data.
#
# *   The goal of EDA is not to arrive at a certain right answer or to confirm a pre-defined hypothesis. It is an exploratory process to draw inferences and get ideas on how the data can be further utilised to predict certain outcomes/develop ML models

# %% [markdown]
# #Introduction to the Electric Vehicles
# * An electric vehicle (EV) is a vehicle that uses one or more electric motors for propulsion. It can be powered by a collector system, with electricity from extravehicular sources, or it can be powered autonomously by a battery (sometimes charged by solar panels, or by converting fuel to electricity using fuel cells or a generator).
#
# * EVs include, but are not limited to, road and rail vehicles, surface and underwater vessels, electric aircraft , and electric spacecraft.
#
# * For road vehicles, together with other emerging automotive technologies such as autonomous driving, connected vehicles, and shared mobility, EVs form a future mobility vision called Connected, Autonomous, Shared, and Electric (CASE) Mobility.
#
# * EVs first came into existence in the late 19th century, when electricity was among the preferred methods for motor vehicle propulsion, providing a level of comfort and ease of operation that could not be achieved by the gasoline cars of the time.
#
# * Internal combustion engines were the dominant propulsion method for cars and trucks for about 100 years, but electric power remained commonplace in other vehicle types, such as trains and smaller vehicles of all types.
#
# * We will be downloading the electric vehicle and population data set from https://www.kaggle.com/

# %% [markdown]
# #About Dataset
# * This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through the Washington State Department of Licensing (DOL).
#
# 1. A Battery Electric Vehicle (BEV) is an all-electric vehicle using one or more batteries to store the electrical energy that powers the motor and is charged by plugging the vehicle into an electric power source.
#
# 2. Alternative Fuel Vehicle (CAFV) Eligibility is based on the fuel requirement and electric-only range requirement as outlined in RCW 82.08.809 and RCW 82.12.809 to be eligible for Alternative Fuel Vehicles retail sales and Washington State use tax exemptions.
#
# 3. Monthly count of vehicles for a county may change from this report and prior reports. Processes were implemented to more accurately assign county at the time of registration.
#
# 4. Electric Range is no longer maintained for Battery Electric Vehicles (BEV) because new BEVs have an electric range of 30 miles or more. Zero (0) will be entered where the electric range has not been researched.
#
# 5. Field 'Electric Utility' was added starting with the publication in March 2022.
#
# 6. Field '2020 Census Tract' was added starting with the publication in June 2022.

# %% [markdown]
# #PROJECT OUTINE
#
# The steps involved in the process of Exploratory Data Analysis are.,
#
# Import the required libraries and its dependencies.
#
# Download the dataset.
#
# Data preparation and cleaning it.
#
# Exploratory Analysis.
#
# Ask and solve questions from the data.
#
# Pictorial representation of data using visualization techniques.

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Read Dataset

# %%
df=pd.read_csv("/content/Electric_Vehicle_Population_Data.csv")

# %%
df.shape
# Out:
# (223995, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223995 entries, 0 to 223994
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         223995 non-null  object
#  1   County                                             223992 non-null  object
#  2   City                                               223992 non-null  object
#  3   State                                              223995 non-null  object
#  4   Postal Code                                        223992 non-null  float64
#  5   Model Year                                         223995 non-null  int64
#  6   Make                                               223995 non-null  object
#  7   Model                                              223995 non-null  object
# ...

# %%
df.head()
# Out:
#    VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0  1C4JJXP66P     Kitsap       Poulsbo    WA      98370.0        2023
# 1  1G1FX6S08K  Snohomish  Lake Stevens    WA      98258.0        2019
# 2  WBY1Z2C58F       King       Seattle    WA      98116.0        2015
# 3  5YJ3E1EBXK       King       Seattle    WA      98178.0        2019
# 4  5YJSA1V24F     Yakima         Selah    WA      98942.0        2015
#
#         Make     Model                   Electric Vehicle Type  \
# 0       JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  CHEVROLET   BOLT EV          Battery Electric Vehicle (BEV)
# 2        BMW        I3          Battery Electric Vehicle (BEV)
# 3      TESLA   MODEL 3          Battery Electric Vehicle (BEV)
# 4      TESLA   MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0             Not eligible due to low battery range            21.0
# ...

# %% [markdown]
# #Identify Null Values

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        18
# Base MSRP                                             18
# Legislative District                                 474
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       3
# ...

# %%
cols = df.columns
def unique_values(df):
    for col in df.columns:
        print(f"There are {df[col].nunique()} unique values in '{col}' column out of {len(df.columns)}")
unique_values(df)
# Out:
# There are 13175 unique values in 'VIN (1-10)' column out of 17
# There are 207 unique values in 'County' column out of 17
# There are 789 unique values in 'City' column out of 17
# There are 48 unique values in 'State' column out of 17
# There are 954 unique values in 'Postal Code' column out of 17
# There are 21 unique values in 'Model Year' column out of 17
# There are 46 unique values in 'Make' column out of 17
# There are 164 unique values in 'Model' column out of 17
# There are 2 unique values in 'Electric Vehicle Type' column out of 17
# There are 3 unique values in 'Clean Alternative Fuel Vehicle (CAFV) Eligibility' column out of 17
# There are 109 unique values in 'Electric Range' column out of 17
# There are 31 unique values in 'Base MSRP' column out of 17
# There are 49 unique values in 'Legislative District' column out of 17
# There are 223995 unique values in 'DOL Vehicle ID' column out of 17
# There are 952 unique values in 'Vehicle Location' column out of 17
# ...

# %%
df['Postal Code'].value_counts().value_counts()
# Out:
# count
# 1       369
# 2        72
# 3        30
# 4        24
# 6        12
#        ...
# 21        1
# 24        1
# 5511      1
# 15        1
# 3009      1
# Name: count, Length: 311, dtype: int64

# %%
df['DOL Vehicle ID'].value_counts().value_counts()
# Out:
# count
# 1    223995
# Name: count, dtype: int64

# %%
df.describe(include="object")
# Out:
#         VIN (1-10)  County     City   State    Make    Model  \
# count       223995  223992   223992  223995  223995   223995
# unique       13175     207      789      48      46      164
# top     7SAYGDEE7P    King  Seattle      WA   TESLA  MODEL Y
# freq          1179  113169    35664  223521   96180    46583
#
#                  Electric Vehicle Type  \
# count                           223995
# unique                               2
# top     Battery Electric Vehicle (BEV)
# freq                            177151
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# count                                              223995
# unique                                                  3
# top     Eligibility unknown as battery range has not b...
# freq                                               130442
#
#                    Vehicle Location  \
# count                        223985
# unique                          952
# top     POINT (-122.13158 47.67858)
# ...

# %% [markdown]
# #Data Cleaning Process

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
df = df.rename(columns={'VIN (1-10)': 'VIN', 'Model Year': 'Model_Year','Electric Vehicle Type': 'EV_Type','Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'CAFV_Eligibility','Electric Range': 'Electric_Range','Base MSRP': 'Base_MSRP','Vehicle Location': 'Vehicle_Location','Electric Utility': 'Electric_Utility'})

# %%
df['VIN'].value_counts()
# Out:
# VIN
# 7SAYGDEE7P    1179
# 7SAYGDEE6P    1168
# 7SAYGDEE5P    1137
# 7SAYGDEEXP    1131
# 7SAYGDEE8P    1120
#               ...
# 5YJXCDE46G       1
# 1GYKPPRLXP       1
# 5LMYJ9YY2P       1
# W1KCG2EB4R       1
# W1KEG5DB3P       1
# Name: count, Length: 13175, dtype: int64

# %%
missing_percentge=df.isna().sum()/len(df)
missing_percentge
# Out:
# VIN                     0.000000
# County                  0.000013
# City                    0.000013
# State                   0.000000
# Postal Code             0.000013
# Model_Year              0.000000
# Make                    0.000000
# Model                   0.000000
# EV_Type                 0.000000
# CAFV_Eligibility        0.000000
# Electric_Range          0.000080
# Base_MSRP               0.000080
# Legislative District    0.002116
# DOL Vehicle ID          0.000000
# Vehicle_Location        0.000045
# Electric_Utility        0.000013
# 2020 Census Tract       0.000013
# dtype: float64

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# VIN                     0
# County                  0
# City                    0
# State                   0
# Postal Code             0
# Model_Year              0
# Make                    0
# Model                   0
# EV_Type                 0
# CAFV_Eligibility        0
# Electric_Range          0
# Base_MSRP               0
# Legislative District    0
# DOL Vehicle ID          0
# Vehicle_Location        0
# Electric_Utility        0
# 2020 Census Tract       0
# dtype: int64

# %%
df.shape
# Out:
# (223995, 17)

# %%
df1.shape
# Out:
# (223496, 17)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223496 entries, 0 to 223994
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   VIN                   223496 non-null  object
#  1   County                223496 non-null  object
#  2   City                  223496 non-null  object
#  3   State                 223496 non-null  object
#  4   Postal Code           223496 non-null  float64
#  5   Model_Year            223496 non-null  int64
#  6   Make                  223496 non-null  object
#  7   Model                 223496 non-null  object
#  8   EV_Type               223496 non-null  object
#  9   CAFV_Eligibility      223496 non-null  object
#  10  Electric_Range        223496 non-null  float64
#  11  Base_MSRP             223496 non-null  float64
#  12  Legislative District  223496 non-null  float64
#  13  DOL Vehicle ID        223496 non-null  int64
# ...

# %%
df1.columns
# Out:
# Index(['VIN', 'County', 'City', 'State', 'Postal Code', 'Model_Year', 'Make',
#        'Model', 'EV_Type', 'CAFV_Eligibility', 'Electric_Range', 'Base_MSRP',
#        'Legislative District', 'DOL Vehicle ID', 'Vehicle_Location',
#        'Electric_Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# #Univariate Analysis

# %% [markdown]
# Top 10 EV Manufacturers

# %%
top_makes = df1['Make'].value_counts().head(10)
plt.figure(figsize=(8, 4))
sns.barplot(x=top_makes.values, y=top_makes.index, palette='viridis')
plt.title("Top 10 EV Manufacturers")
plt.xlabel("Count")
plt.ylabel("Make")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-bb6dddb2c0e0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_makes.values, y=top_makes.index, palette='viridis')

# %% [markdown]
# *   Top 10 EV Manufacturer is 1.Tesla  2.Chevrolet 3.Nissan 4.Ford 5.KIA 6.BMW 7.Toyota 8.Hyundai 9.Rivian 10.Jeep
#
# *   Tesla is the Highest EV Manufacturer

# %% [markdown]
# #EV Type Distribution

# %%
ev_type_counts = df1['EV_Type'].value_counts()
sns.barplot(x=ev_type_counts.values, y=ev_type_counts.index, palette='Set2')
plt.title("EV Type Distribution")
plt.xlabel("Count")
plt.ylabel("EV Type")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-38-bd2a689a633d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ev_type_counts.values, y=ev_type_counts.index, palette='Set2')

# %% [markdown]
# * Battery Electric Vehicles (BEVs) make up the majority of the registered EVs in the dataset.
#
# * Plug-in Hybrid Electric Vehicles (PHEVs) are present but in significantly lower numbers.
#
# * This suggests a shift in consumer preference toward fully electric vehicles, likely due to improvements in range, charging infrastructure, and environmental incentives.

# %% [markdown]
# #Model Year Distribution

# %%
sns.histplot(df1['Model_Year'], kde=True, bins=15, color='skyblue')
plt.title("Model Year Distribution")
plt.xlabel("Model Year")
plt.ylabel("Number of Vehicles")
plt.tight_layout()
plt.show()

# %% [markdown]
# * There's a sharp increase in the number of registered electric vehicles starting around 2018.
#
# * The peak is around 2022- 2023, indicating the highest number of new EVs in those years.
#
# * Very few EVs are from before 2010, showing EV adoption was minimal in earlier years.

# %% [markdown]
# #Electric Range Distribution

# %%
sns.histplot(df1['Electric_Range'], kde=True, bins=30, color='lightgreen')
plt.title("Electric Range Distribution")
plt.xlabel("Electric Range (miles)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223496 entries, 0 to 223994
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         223496 non-null  object
#  1   County                                             223496 non-null  object
#  2   City                                               223496 non-null  object
#  3   State                                              223496 non-null  object
#  4   Postal Code                                        223496 non-null  float64
#  5   Model Year                                         223496 non-null  int64
#  6   Make                                               223496 non-null  object
#  7   Model                                              223496 non-null  object
# ...

# %% [markdown]
# #Base MSRP(Price)Distribution

# %%
sns.histplot(df1['Base_MSRP'], kde=True, bins=30, color='salmon')
plt.title("Base MSRP (Price) Distribution of EVs")
plt.xlabel("Base MSRP")
plt.ylabel("Number of Vehicles")
plt.tight_layout()
plt.show()

# %% [markdown]
# The vast majority of EVs are priced well below $100,000, clustering heavily at the lower end.
# This suggests that most EVs are relatively affordable, aimed at the mass market, while only a few high-end luxury models exist.

# %% [markdown]
# 1. What is the Distances Travel by vehicle make per electric charge?

# %% [markdown]
# #Bivariate Anlaysis

# %% [markdown]
# # Electric Range vs Model Year

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df1, x='Model_Year', y='Electric_Range', palette='coolwarm')
plt.title("Electric Range vs Model Year")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-117-3a2ffae11200>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Filter electric range to > 50 miles
df2 = df1[df1['Electric_Range'] > 50]

# Filter model year to realistic range
df2 = df[df['Model_Year'] <= 2024]

# %% [markdown]
# Before
# Many low-range vehicles crowd the plot
# 2023-2025 look broken
# Misleading trend
#
# After
# Only real EVs (good ranges) shown
# Only valid model years till 2024
# Clear improvement in electric range over year

# %%
sns.boxplot(data=df2, x='Model_Year', y='Electric_Range')
plt.title('Electric Range vs Model Year')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Before 2015, most vehicles had electric ranges below 100 miles.
# From 2015 onwards, there's a noticeable rise in the median range and the upper range limit.

# %%
df1.columns
# Out:
# Index(['VIN', 'County', 'City', 'State', 'Postal Code', 'Model_Year', 'Make',
#        'Model', 'EV_Type', 'CAFV_Eligibility', 'Electric_Range', 'Base_MSRP',
#        'Legislative District', 'DOL Vehicle ID', 'Vehicle_Location',
#        'Electric_Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# #Electric Range by EV Type

# %%
sns.boxplot(data=df1, x='EV_Type', y='Electric_Range', palette='Set3')
plt.title("Electric Range by EV Type")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-119-e179689a1b7d>:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

top_20_utilities = df1['Electric_Utility'].value_counts().nlargest(15).index
df_filtered = df1[df1['Electric_Utility'].isin(top_20_utilities)]

utility_year_counts = df_filtered.groupby(['Model_Year', 'Electric_Utility']).size().unstack(fill_value=0)

plt.figure(figsize=(16, 8))
utility_year_counts.plot(kind='bar', stacked=True, figsize=(16, 8))
plt.title('Electric Utility Distribution by Model Year (Top 15 Utilities)')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles')
plt.legend(title='Electric_Utility', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
n_top_makes = 5

top_n_makes = df1['Make'].value_counts().nlargest(n_top_makes).index
df_filtered = df1[df1['Make'].isin(top_n_makes)]

plt.figure(figsize=(16, 8))
sns.countplot(x='Model_Year', hue='Make', data=df_filtered)
plt.title(f'Vehicle Makes by Model Year (Top {n_top_makes} Makes)')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles')
plt.legend(title='Make', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Model_Year', hue='EV_Type', data=df1)
plt.title('Electric Vehicle Type Distribution by Model Year')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles')
plt.legend(title='EV_Type')
plt.tight_layout()
plt.show()

# %%
top_10_makes = df1['Make'].value_counts().nlargest(10).index

plt.figure(figsize=(12, 6))
sns.countplot(x='Make', hue='EV_Type', data=df1[df1['Make'].isin(top_10_makes)],
              order=top_10_makes)
plt.title('Electric Vehicle Type Distribution by Top 10 Makes')
plt.xlabel('Number of Vehicles')
plt.ylabel('Make')
plt.legend(title='EV_Type')
plt.tight_layout()
plt.show()

# %%
top_10_makes = df1['Make'].value_counts().nlargest(10).index

plt.figure(figsize=(12,6))
sns.countplot(x='Make', hue='EV_Type', data=df1[df1['Make'].isin(top_10_makes)],
              order=top_10_makes)
plt.title('Electric Vehicle Type Distribution by Top 10 Makes')
plt.xlabel('Make')
plt.ylabel('Number of Vehicles')
plt.legend(title='EV_Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
top_10_makes = df1['Make'].value_counts().nlargest(10).index

plt.figure(figsize=(12, 6))
sns.boxplot(x='Make', y='Base_MSRP', data=df1[df1['Make'].isin(top_10_makes)])
plt.title('Base MSRP Distribution by Top 10 Makes')
plt.xlabel('Make')
plt.ylabel('Base MSRP (USD)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(y='State', hue='CAFV_Eligibility', data=df1,
              order=df1['State'].value_counts().index)
plt.title('CAFV Eligibility Distribution by State')
plt.xlabel('Number of Vehicles')
plt.ylabel('State')
plt.legend(title='CAFV Elig.', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Filter out the rows where CAFV Eligibility is 'Eligibility unknown as battery range has not been researched'
df_filtered = df1[df1['CAFV_Eligibility'] != 'Eligibility unknown as battery range has not been researched']

plt.figure(figsize=(10, 6))
sns.countplot(y='State', hue='CAFV_Eligibility', data=df_filtered,
              order=df_filtered['State'].value_counts().index)
plt.title('CAFV Eligibility Distribution by State')
plt.xlabel('Number of Vehicles')
plt.ylabel('State')
plt.legend(title='CAFV Elig.', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_filtered = df1[df1['CAFV_Eligibility'] != 'Eligibility unknown as battery range has not been researched']

top_10_counties = df_filtered['County'].value_counts().nlargest(10).index
df_top_10_counties = df_filtered[df_filtered['County'].isin(top_10_counties)]

plt.figure(figsize=(12, 6))
sns.countplot(y='County', hue='CAFV_Eligibility', data=df_top_10_counties,
              order=top_10_counties)
plt.title('CAFV Eligibility Distribution by Top 10 Counties (Excluding Unknown)')
plt.xlabel('Number of Vehicles')
plt.ylabel('County')
plt.legend(title='CAFV Elig.')
plt.tight_layout()
plt.show()

# %%
top_5_makes = df['Make'].value_counts().nlargest(5).index
df_top_5_makes = df[df['Make'].isin(top_5_makes)]

# Group by Model Year and Make, then count the occurrences
make_by_year = df_top_5_makes.groupby(['Model_Year', 'Make']).size().unstack(fill_value=0)

# Create the stacked bar chart
plt.figure(figsize=(12, 6))
make_by_year.plot(kind='bar', stacked=True, colormap='viridis') # You can change 'viridis' to other colormaps
plt.title('Vehicle Makes by Model Year (Top 5 Makes)')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Make', bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Electric_Range', y='Base_MSRP', hue='Make', data=df1)
plt.title('Base MSRP vs. Electric Range by Make')
plt.xlabel('Electric Range (miles)')
plt.ylabel('Base MSRP (USD)')
plt.legend(title='Make', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223496 entries, 0 to 223994
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   VIN                   223496 non-null  object
#  1   County                223496 non-null  object
#  2   City                  223496 non-null  object
#  3   State                 223496 non-null  object
#  4   Postal Code           223496 non-null  float64
#  5   Model_Year            223496 non-null  Int64
#  6   Make                  223496 non-null  object
#  7   Model                 223496 non-null  object
#  8   EV_Type               223496 non-null  object
#  9   CAFV_Eligibility      223496 non-null  object
#  10  Electric_Range        223496 non-null  float64
#  11  Base_MSRP             223496 non-null  float64
#  12  Legislative District  223496 non-null  float64
#  13  DOL Vehicle ID        223496 non-null  int64
# ...

# %% [markdown]
# #Base MSRP by EV Type

# %%
sns.boxplot(x='EV_Type', y='Base_MSRP', data=df1, palette='Pastel2')
plt.title("Base MSRP by EV Type")
plt.xlabel("EV Type")
plt.ylabel("Base MSRP ($)")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-120-d8f68b9cdf16>:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# #Base MSRP by Model Year and EV Type

# %%
sns.scatterplot(data=df1, x='Model_Year', y='Base_MSRP', hue='EV_Type', alpha=0.6)
plt.title("Base MSRP by Model Year and EV Type")
plt.tight_layout()
plt.show()

# %% [markdown]
# Both types of EVs have increased in variety since 2010.
#
# Recent years (2015-2022) show denser clustering, indicating a growth in EV model availability.
#
# Most new models are BEVs, suggesting a market shift towards full electric rather than hybrids.

# %%
sns.scatterplot(df1, x='Electric_Range', y='Base_MSRP', hue='Make', alpha=0.6, legend=False)
plt.title("Base MSRP vs Electric Range (by Make)")
plt.tight_layout()
plt.show()

# %%
top_makes = df1['Make'].value_counts().head(10).index
df_top_makes = df1[df1['Make'].isin(top_makes)]

plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=df_top_makes,
    x='Base_MSRP',
    y='Electric_Range',
    hue='Make',
    palette='tab10',
    alpha=0.7
)
plt.title("Electric Range vs. MSRP by Top 6 EV Brands")
plt.xlabel("Base MSRP ($)")
plt.ylabel("Electric Range (miles)")
plt.legend(title='Make', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Correlation Heatmap of EV Features

# %%
# Numerical Columns
numerical_df = df1[['Electric_Range', 'Base_MSRP', 'Model_Year']].copy()

correlation_matrix = numerical_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Features')
plt.tight_layout()
plt.show()

# %%
pivot_table = df1.groupby(['Make', 'Model_Year']).size().unstack(fill_value=0)

plt.figure(figsize=(12, 10))
sns.heatmap(pivot_table, cmap='viridis', annot=True, fmt="d")
plt.title('Vehicle Count by Make and Model Year')
plt.xlabel('Model Year')
plt.ylabel('Make')
plt.tight_layout()
plt.show()

# %% [markdown]
# 2.What is the Year Wise Cars sales growth?

# %%
year_wise_cars = df.groupby('Model_Year')['VIN'].count().reset_index()
year_wise_cars.columns = ['year','num_cars']

fig = ps.line(year_wise_cars,x="year", y="num_cars", title='Year Wise Number of EV',markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 3. What is the Top 10 count of cars per city?

# %%
car_counts_Cty = df['City'].value_counts().nlargest(10)

car_counts_Cty.plot(kind='bar')
plt.xlabel('City')
plt.ylabel('Number of Cars')
plt.title('Top 10 Count of Cars per City')
plt.show()


car_counts_cty_df = car_counts_Cty.to_frame()
car_counts_cty_df.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c47a5_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c47a5_row1_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_c47a5_row2_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_c47a5_row3_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_c47a5_row4_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_c47a5_row5_col0, #T_c47a5_row6_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_c47a5_row7_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c47a5_row8_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c47a5_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_c47a5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c47a5_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
# ...

# %%
top_10_models = df1['Model'].value_counts().nlargest(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_models.index, y=top_10_models.values, palette='viridis')
plt.title('Top 10 Most Frequent Vehicle Models')
plt.xlabel('Model')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

print("\nTop 10 Most Frequent Vehicle Models:")
print(top_10_models)
# Out:
# <ipython-input-201-ce797a9937ac>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Top 10 Most Frequent Vehicle Models:
# Model
# MODEL Y           46476
# MODEL 3           34378
# LEAF              13725
# MODEL S            7740
# BOLT EV            6998
# MODEL X            6229
# MUSTANG MACH-E     4765
# VOLT               4710
# ID.4               4642
# WRANGLER           4275
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 7))
county_counts = df1['County'].value_counts().nlargest(10) # Display top 20 counties
sns.barplot(x=county_counts.values, y=county_counts.index, palette='viridis')
plt.title('Top 10 Counties by Vehicle Count')
plt.xlabel('Number of Vehicles')
plt.ylabel('County')
plt.tight_layout()
plt.show()

print("\nTop 10 Counties by Vehicle Count:")
print(df1['County'].value_counts().head(10))
# Out:
# <ipython-input-162-b1a987fa546c>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# Top 10 Counties by Vehicle Count:
# County
# King         113154
# Snohomish     27184
# Pierce        18026
# Clark         13447
# Thurston       8252
# Kitsap         7476
# Spokane        6293
# Whatcom        5447
# Benton         2892
# Skagit         2523
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 7))
utility_counts = df1['Electric_Utility'].value_counts().nlargest(10) # Display top 20 for readability
sns.barplot(x=utility_counts.values, y=utility_counts.index, palette='Spectral')
plt.title('Top 10 Electric Utilities by Vehicle Count')
plt.xlabel('Number of Vehicles')
plt.ylabel('Electric Utility')
plt.tight_layout()
plt.show()

print("\nTop 10 Electric Utilities by Vehicle Count:")
print(df1['Electric_Utility'].value_counts().head(10))
# Out:
# <ipython-input-203-cfaab89018ef>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# Top 10 Electric Utilities by Vehicle Count:
# Electric_Utility
# PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)                                      81167
# PUGET SOUND ENERGY INC                                                             46324
# CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)                                       38191
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)                   13130
# BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY    10077
# PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY                                  5146
# BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||INLAND POWER & LIGHT COMPANY          3820
# ...

# %% [markdown]
# 4. What are the Top 10 count of cars per state?

# %%
car_counts_St = df['State'].value_counts().nlargest(10)

# plot the counts with a logarithmic y-axis
plt.bar(car_counts_St.index, car_counts_St.values)
plt.yscale('log')
plt.xlabel('State')
plt.ylabel('Number of Cars (log scale)')
plt.title('Top 10 Count of Cars per State')
plt.show()

# %% [markdown]
# 6. In which Year Electric Vehicles increased?

# %%
sns.histplot(data=df, x="Model_Year", bins=20)
# Out:
# <Axes: xlabel='Model_Year', ylabel='Count'>

# %% [markdown]
# 7. What are the Top 5 vs Bottom 5 Comparison?

# %%
car_market_share = pd.DataFrame(df.groupby('Make')['VIN'].count().reset_index()).sort_values(by='VIN',ascending=False).reset_index(drop=True)
car_market_share.columns = ['Model','Count']
car_market_share_top_5 = car_market_share.head(5)
car_market_share_bottom_5 = car_market_share.tail(5)

fig, axes = plt.subplots(1, 2, figsize=(20, 5))
sns.barplot(data=car_market_share_top_5, x="Model", y="Count",ax=axes[0])
sns.barplot(data=car_market_share_bottom_5, x="Model", y="Count",ax=axes[1])
axes[0].set_title('Top 5 Cars')
axes[1].set_title('Bottom 5 Cars')
# Out:
# Text(0.5, 1.0, 'Bottom 5 Cars')

# %% [markdown]
# #Summary
# Here is a brief summary of the process we followed for the Exploratory Data Analysis of Electric Vehicle and Population Data.
#
# * downloaded the data using opendatasets library from Kaggle.
# * Will have performed below actions on the Data.
# * Load the file using pandas.
# * Look at some information about the file.
# * Fix any missing or incorrect values.
# * analysed below columns to get meangingful insights out of it.
#    * City
#    * Model(TESLA in maximum cities and minimum cities)
#    * Make
#    * Base MSRP
#    * Electric Utility
#    * VIN
#    * No of EV per County
#    * Electric Range per Clean Alternative Fuel Vehicle (CAFV) Eligibility
#    * Vehicle Location
#    * Relation Between Electric Range And Base MSRP

# %% [markdown]
# #Conclusion
# * Seattle is the top city in top 10 with electric Cars.
# * King County is the top in top 10 county with more electric Vehicles
# * JAGUR have the more electric range comapre to other makes.
# * From 2010 to 2024 the no of electric vehicles are increased.
# * Tesla is the most popular electric car make in Washington state, followed by Nissan, Chevrolet, and Toyota.
# * Tesla is also the most popular make in Seattle, followed by Nissan, Chevrolet, and BMW.
# * Washington state has the highest number of BMW, and Chevrolet electric cars registered among all states.
